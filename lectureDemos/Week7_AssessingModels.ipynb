# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Large Random Samples

# %%
united = Table.read_table('united.csv')
united = united.with_column('Row', np.arange(united.num_rows)).move_to_start('Row')
united_bins = np.arange(-20, 201, 5)

# %%
# (Population) Probability Distribution
united.hist('Delay', bins = united_bins)

# %%
# (Sample) Empirical Distribution
united.sample(10).hist('Delay', bins = united_bins)

# %%
# (Sample) Empirical Distribution
united.sample(1000).hist('Delay', bins = united_bins)

# %% [markdown]
# ## Statistics

# %%
# (Population) Parameter
np.median(united.column('Delay'))
# Out:
# 2.0

# %%
# (Sample) Statistic
np.median(united.sample(10).column('Delay'))
# Out:
# -1.0

# %%
# (Sample) Statistic
np.median(united.sample(100).column('Delay'))
# Out:
# 3.5

# %% [markdown]
# ### Probability & Empirical Distributions of a Statistic

# %%
def sample_median(size):
    return np.median(united.sample(size).column('Delay'))

# %%
sample_median(10)
# Out:
# 3.5

# %%
#TODO: let;s simulate the statistic median 5 and 2000 times and accumulate samples into an array

# %%
#TODO: create a table and visualize the ditribution (look at the histogram)

# %%
#TODO: add more samples. What does the histogram show?

# %% [markdown]
# ## Swain vs. Alabama ##

# %%
#TODO: make an array to represent the population proportions

# %%
#TODO: use the function sample_proportions() to sample from the population 100 times

# %%
#TODO create a function to return a randomized proportion selected for the panel of 100 
def panel_proportion():
    ...

# %%
#TODO: let's simulate 10000 repetitions of this random selection

# %%
#TODO: can you visualize the date from the simulation using a histogram? What do you see?

# %% [markdown]
# ## Mendel and Pea Flowers ##

# %%
## Mendel had 929 plants, of which 709 had purple flowers
observed_purples = ...
observed_purples
# Out:
# Ellipsis

# %%
#TODO: simulate the model & make a function to simulate 1 iteration of this experiment 
# and look at just purple flowers

# %%
def purple_flowers():
    ...

# %%
purple_flowers()

# %%
#simulate 10000 iterations of this experiment

# %%
#Let's visualize with a histogram. Does this tell us if our model is good? 
#What is the statistic we may want to simulate/visualize?

# %%
#What is the statistic when looking at
# Out:
# 1.318622174381062
